# %%
##Import needed libraries
from math import exp
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
##Import CSV
dfFantasyData = pd.read_csv ('footballdata.csv')

dfFantasyData
# Out:
#      Unnamed: 0           Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Games  \
# 0          Year                 Name         Tm    FantPos        Age     G
# 1          2008           Drew Brees        NOR         QB         29    16
# 2          2008        Aaron Rodgers        GNB         QB         25    16
# 3          2008        Philip Rivers        SDG         QB         27    16
# 4          2008    DeAngelo Williams        CAR         RB         25    16
# 5          2008           Jay Cutler        DEN         QB         25    16
# 6          2008          Kurt Warner        ARI         QB         37    16
# 7          2008       Michael Turner        ATL         RB         26    16
# 8          2008       Peyton Manning        IND         QB         32    16
# 9          2008       Donovan McNabb        PHI         QB         32    16
# 10         2008          Matt Cassel        NWE         QB         26    16
# ...

# %%
##Clean data of NA values for positions
noNADataPos = dfFantasyData.dropna(subset = ["Unnamed: 3"])
noNADataPos

# ##Lets just say we want the best score with a QB, RB, WR
position = {'QB': 0,'RB': 1, 'WR': 2}
# ##Lets drop all other positions so we can focus on these 
df3 = noNADataPos[(noNADataPos['Unnamed: 3'].isin(["QB","RB","WR"]))]

df3
#Lets binarize team, and position
df3['Unnamed: 3'] = df3['Unnamed: 3'].map(position)
# #Drop columns for y values we dont care about (PPRPG, PPG Pos Rank)
# dfCleanerData = noNADataPos.drop(['Unnamed: 23', 'Unnamed: 24', 'Fantasy.2'], axis=1)
# dfCleanerData

# #drop the faux headers dont really care 
# dfNoHeaders = dfCleanerData.drop(dfCleanerData.index[0])

# #Our PPR values will be our y values 
# #y_values = df[['Fantasy.1']]


# ##We are going to separate the names of the players, we will later return the index of the players names with the
# ##prediction once finished 
# names = dfNoHeaders[['Unnamed: 1']]

# dfNoHeaders.drop(['Unnamed: 1'])
# Out:
# /Users/cassidy/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':

# %%
##Make model / select model / train

# %%
##Test model

# %%
##Return results
